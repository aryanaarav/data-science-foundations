# %% [markdown]
# # Practical Statistics for Data Scientists (Python)
# # Chapter 1. Exploratory Data Analysis
# > (c) 2019 Peter C. Bruce, Andrew Bruce, Peter Gedeck

# %%
# %matplotlib inline

from pathlib import Path

import pandas as pd
import numpy as np
from scipy.stats import trim_mean
from statsmodels import robust
import wquantiles

import seaborn as sns
import matplotlib.pylab as plt

# %%
from pathlib import Path
import os

DATA = Path(r'D:\data-science-foundations\Statistics\Chapter1_Exploratory_Data_Analysis\data')
print(DATA)
print(DATA.exists())
print(list(DATA.glob('*.csv')))
# Out:
# D:\data-science-foundations\Statistics\Chapter1_Exploratory_Data_Analysis\data
# True
# ...

# %%
try:
    import common
    DATA = common.dataDirectory()
except ImportError:
    DATA = Path(r'D:\data-science-foundations\Statistics\Chapter1_Exploratory_Data_Analysis\data')

# %%
from pathlib import Path

DATA = Path(r'D:\data-science-foundations\Statistics\Chapter1_Exploratory_Data_Analysis\data')
print("Path exists:", DATA.exists())
print("Path is directory:", DATA.is_dir())
print("\nFiles in directory:")
for file in DATA.iterdir():
    print(f"  {file.name}")
# Out:
# Path exists: True
# Path is directory: True
#
# Files in directory:
#   airline_stats.csv
#   click_rates.csv
#   dfw_airline.csv
#   four_sessions.csv
#   housetasks.csv
#   house_sales.csv
#   imanishi_data.csv
#   lc_loans.csv
#   loan200.csv
#   loan3000.csv
#   loans_income.csv
#   loan_data.csv.gz
#   LungDisease.csv
#   sp500_data.csv.gz
#   sp500_sectors.csv
#   statedata.csv
#   web_page_data.csv

# %%
AIRLINE_STATS_CSV = DATA / 'airline_stats.csv'
KC_TAX_CSV = DATA / 'kc_tax.csv.gz'
LC_LOANS_CSV = DATA / 'lc_loans.csv'
AIRPORT_DELAYS_CSV = DATA / 'dfw_airline.csv'
SP500_DATA_CSV = DATA / 'sp500_data.csv.gz'
SP500_SECTORS_CSV = DATA / 'sp500_sectors.csv'
STATE_CSV = DATA / 'statedata.csv'

# %%
# Table 1-2
state = pd.read_csv(STATE_CSV)
print(state.head(8))
# Out:
#    Population  Income  Illiteracy  Life.Exp  Murder  HS.Grad  Frost    Area  \
# 0        3615    3624         2.1     69.05    15.1     41.3     20   50708
# 1         365    6315         1.5     69.31    11.3     66.7    152  566432
# 2        2212    4530         1.8     70.55     7.8     58.1     15  113417
# 3        2110    3378         1.9     70.66    10.1     39.9     65   51945
# 4       21198    5114         1.1     71.71    10.3     62.6     20  156361
# 5        2541    4884         0.7     72.06     6.8     63.9    166  103766
# 6        3100    5348         1.1     72.48     3.1     56.0    139    4862
# 7         579    4809         0.9     70.06     6.2     54.6    103    1982
#
#   state.abb  state.area         x        y      state.division   state.name  \
# 0        AL       51609  -86.7509  32.5901  East South Central      Alabama
# 1        AK      589757 -127.2500  49.2500             Pacific       Alaska
# ...

# %%
df = pd.DataFrame(state)
df.head(5)
# Out:
#    Population  Income  Illiteracy  Life.Exp  Murder  HS.Grad  Frost    Area  \
# 0        3615    3624         2.1     69.05    15.1     41.3     20   50708
# 1         365    6315         1.5     69.31    11.3     66.7    152  566432
# 2        2212    4530         1.8     70.55     7.8     58.1     15  113417
# 3        2110    3378         1.9     70.66    10.1     39.9     65   51945
# 4       21198    5114         1.1     71.71    10.3     62.6     20  156361
#
#   state.abb  state.area         x        y      state.division  state.name  \
# 0        AL       51609  -86.7509  32.5901  East South Central     Alabama
# 1        AK      589757 -127.2500  49.2500             Pacific      Alaska
# 2        AZ      113909 -111.6250  34.2192            Mountain     Arizona
# 3        AR       53104  -92.2992  34.7336  West South Central    Arkansas
# 4        CA      158693 -119.7730  36.5341             Pacific  California
#
#   state.region
# 0        South
# 1         West
# ...
